# %% [markdown]
# <a href="https://colab.research.google.com/github/Lifestaxx/PROGCOM-A/blob/main/Ejercicios_diccionarios_Escuadron_Delta(Y_Guillermo).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
nombres=["Juan","Santiago","Guillermo","Clemencia","Sahian","Laura","Johan"]
apellidos=["Suárez","Sanabria","Varela","Higuera","Custodio","Avellaneda","Vargas"]
sexo=["Masculino","Femenino"]
for i in range(1,random.randint(1,500)) :
  pasajero={"Nombre":nombres[random.randint(0,6)],"Apellido":apellidos[random.randint(0,6)],"Pais":random.choice([True,False]),"Interpol":random.choice([True,False]),"Sexo":sexo[int(random.uniform(0,2))]}
  print(pasajero)
  if pasajero["Nombre"]=="Juan" or pasajero["Nombre"]=="Santiago" or pasajero["Nombre"]=="Guillermo" or pasajero["Nombre"]=="Johan":
    if pasajero["Sexo"]=="Masculino":
      ns=True
    else:
      ns=False
  elif pasajero["Nombre"]=="Clemencia" or pasajero["Nombre"]=="Sahian" or pasajero["Nombre"]=="Laura":
    if pasajero["Sexo"]=="Femenino":
      ns=True
    else:
      ns=False
  if pasajero["Pais"]==False and pasajero["Interpol"]==False and ns==True:
    print("Felicidades " ,pasajero["Nombre"],pasajero["Apellido"], " usted cumple con todos los requisitos para ingresar al país")
  if pasajero["Pais"]==True:
    print("Lo sentimos " ,pasajero["Nombre"],pasajero["Apellido"], " pero usted no puede ingresar al país debido a que su país se encuentra en guerra")
  if pasajero["Interpol"]==True:
    print("Lo sentimos " ,pasajero["Nombre"],pasajero["Apellido"], " pero usted no puede ingresar al país debido a que usted se encuentra buscado por la interpol")
  if ns==False:
    print("Lo sentimos " ,pasajero["Nombre"],pasajero["Apellido"], " pero usted no puede ingresar al país debido a que su nombre no corresponde con el sexo de su pasaporte")
  continuar=int(input("¿Desea continuar con el siguiente pasajero? 1.Si 2.No "))
  if continuar>2:
    while continuar>2:
      print("Ingrese un número válido e intente de nuevo")
      continuar=int(input("¿Desea continuar con el siguiente pasajero? 1.Si 2.No "))
  if continuar==2:
    print("Entendible, disfrute su descanso")
    break
# Out:
# {'Nombre': 'Clemencia', 'Apellido': 'Avellaneda', 'Pais': True, 'Interpol': False, 'Sexo': 'Masculino'}
# Lo sentimos  Clemencia Avellaneda  pero usted no puede ingresar al país debido a que su país se encuentra en guerra
# Lo sentimos  Clemencia Avellaneda  pero usted no puede ingresar al país debido a que su nombre no corresponde con el sexo de su pasaporte
# ¿Desea continuar con el siguiente pasajero? 1.Si 2.No 1
# {'Nombre': 'Laura', 'Apellido': 'Custodio', 'Pais': True, 'Interpol': True, 'Sexo': 'Masculino'}
# Lo sentimos  Laura Custodio  pero usted no puede ingresar al país debido a que su país se encuentra en guerra
# Lo sentimos  Laura Custodio  pero usted no puede ingresar al país debido a que usted se encuentra buscado por la interpol
# Lo sentimos  Laura Custodio  pero usted no puede ingresar al país debido a que su nombre no corresponde con el sexo de su pasaporte
# ¿Desea continuar con el siguiente pasajero? 1.Si 2.No 1
# ...

# %%
import pandas as pd
import random
item={"Empanada":3000,"Flauta":2500,"Coca-Cola":2500,"Mieltertos":300,"Monster":6800,"Hamburguesa":5000,"Malteada":7000,"Pepsi":2200,"Vive 100":3800, "Speed Max":2900}
precio=0
total=0
articulos=[]
precios=[]
lista_items=item.keys()
lista_items=list(lista_items)
for i in range(1,random.randint(1,10)):
  c=random.randint(0,9)
  articulos.append(lista_items[c])
  precios.append(item[lista_items[c]])
  total=total+item[lista_items[c]]
articulos.append("Total")
precios.append(total)
factura={"Artículos":articulos,"Precios":precios}
pd.DataFrame.from_dict(factura)
# Out:
#    Artículos  Precios
# 0   Vive 100     3800
# 1      Pepsi     2200
# 2  Coca-Cola     2500
# 3   Vive 100     3800
# 4   Vive 100     3800
# 5    Monster     6800
# 6  Coca-Cola     2500
# 7     Flauta     2500
# 8      Total    27900
