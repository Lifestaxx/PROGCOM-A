# %% [markdown]
# <a href="https://colab.research.google.com/github/Lifestaxx/PROGCOM-A/blob/main/Ejercicios_taller_con_While.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#12 Desarrollado por Juan Diego Suárez
import time
print("Ingrese el tiempo inicial del temporizador")
min=int(input("Minutos: "))
while (min>60):
  print("No puede ingresar un valor mayor a 60, intente de nuevo")
  min=int(input("Minutos: "))
s=int(input("Segundos: "))
while (s>60):
  print("No puede ingresar un valor mayor a 60, intente de nuevo")
  s=int(input("Segundos: "))
while s>0:
  s=s-1
  sstr=str(s)
  if len(sstr)==1:
    print(min,s,sep=":0")
  else:
    print(min,s,sep=":")
  time.sleep(1)
if (s==0):
  while min>0:
    s=60
    min=min-1
    while s>0:
      s=s-1
      sstr=str(s)
      if len(sstr)==1:
        print(min,s,sep=":0")
      else:
        print(min,s,sep=":")
    if min==0 and s==0: break
# Out:
# Ingrese el tiempo inicial del temporizador
# Minutos: 1
# Segundos: 20
# 1:19
# 1:18
# 1:17
# 1:16
# 1:15
# 1:14
# 1:13
# 1:12
# 1:11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-8557dda3dfee> in <cell line: 12>()
#      17   else:
#      18     print(min,s,sep=":")
# ---> 19   time.sleep(1)
#      20 if (s==0):
#      21   while min>0:
#
# KeyboardInterrupt:

# %%
# Ejercicio realizado por Santiago Sanabria Torres
nom=str(input("ingrese una palabra "))
c=0
while c<len(nom):
  c=c+1
  print(nom[0:c])
# Out:
# ingrese una palabra sTEVE
# s
# sT
# sTE
# sTEV
# sTEVE

# %%
#realizado con for
nom=str(input("ingrese una palabra "))
c=0
for i in nom:
  c=c+1
  print(nom[0:c])
# Out:
# ingrese una palabra steve
# s
# st
# ste
# stev
# steve

# %%
#Ejercicio desarrollado por juan Sebastian
c=0
while c<10:
  print("programacion")
  c+=1
# Out:
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion

# %%
for c in range(10):
  print("programacion")
# Out:
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion
# programacion

# %%
#7 Realizado por Luigui
i=0
num=[]
while i<10:
  i+=1
  n=int(input(f"Ingrese el numero {i}: "))
  num.append(n)
nmayor=max(num)
nmenor=min(num)
print(f"El número mayor es {nmayor}")
print(f"El número menor es {nmenor}")
# Out:
# Ingrese el numero 1: 1
# Ingrese el numero 2: 2
# Ingrese el numero 3: 3
# Ingrese el numero 4: 4
# Ingrese el numero 5: 5
# Ingrese el numero 6: 6
# Ingrese el numero 7: 7
# Ingrese el numero 8: 8
# Ingrese el numero 9: 9
# Ingrese el numero 10: 10
# El número mayor es 10
# El número menor es 1

# %%
#AHORA CON FOR
num=[]
for i in range(10):
  n=int(input(f"Ingrese el numero {i+ 1}: "))
  num.append(n)
nmayor=max(num)
nmenor=min(num)
print(f"El número mayor es {nmayor}")
print(f"El número menor es {nmenor}")
# Out:
# Ingrese el numero 1: 1
# Ingrese el numero 2: 2
# Ingrese el numero 3: 3
# Ingrese el numero 4: 4
# Ingrese el numero 5: 5
# Ingrese el numero 6: 6
# Ingrese el numero 7: 7
# Ingrese el numero 8: 8
# Ingrese el numero 9: 9
# Ingrese el numero 10: 10
# El número mayor es 10
# El número menor es 1

# %%
#8 Santiago Galvis
#while
contpal=0
contador=0
while contador<10:
  palabra= input("ingrese la palbra ")
  if len(palabra)>5:
    contpal +=1
    print(f"{contpal} de las 10 palabras tienen más de 5 caracteres.")
  contador +=1
# Out:
# ingrese la palbra santiago
# 1 de las 10 palabras tienen más de 5 caracteres.
# ingrese la palbra g
# ingrese la palbra sadfsad
# 2 de las 10 palabras tienen más de 5 caracteres.
# ingrese la palbra hola
# ingrese la palbra cinco
# ingrese la palbra diciembre
# 3 de las 10 palabras tienen más de 5 caracteres.
# ingrese la palbra ayer
# ingrese la palbra zapato
# 4 de las 10 palabras tienen más de 5 caracteres.
# ingrese la palbra hola
# ingrese la palbra s

# %%
contpal=0
for a in range (10):
  palabra= input("ingrese la palbra ")
  if len(palabra)>5:
    contpal +=1
    print(f"{contpal} de las 10 palabras tienen más de 5 caracteres.")
# Out:
# ingrese la palbra sasdsadsadas
# 1 de las 10 palabras tienen más de 5 caracteres.
# ingrese la palbra s
# ingrese la palbra s
# ingrese la palbra s
# ingrese la palbra s
# ingrese la palbra s
# ingrese la palbra s
# ingrese la palbra zapato
# 2 de las 10 palabras tienen más de 5 caracteres.
# ingrese la palbra f
# ingrese la palbra g

# %%
# 20 hecho porJohan Lizcano

num = 10
while num<=31:
  print(num)
  num=num+6
# Out:
# 10
# 16
# 22
# 28

# %%
# con for
for num in range(10,32,6):
  print(num)
# Out:
# 10
# 16
# 22
# 28

# %%
##Ejercicio num 16 desarrollado por Juan David Solano Arias.
##imprimir cadena de caracteres vericalmente
cad= input("Digite una cadena de caracteres por favor.")
ind= 0
while ind<len(cad):
  print(cad[ind])
  ind +=1
# Out:
# Digite una cadena de caracteres por favor.Juanita
# J
# u
# a
# n
# i
# t
# a

# %%
cad= input("Digite una cadena de caracteres por favor.")
for c in cad:
  print(c)
# Out:
# Digite una cadena de caracteres por favor.Juanita
# J
# u
# a
# n
# i
# t
# a

# %% [markdown]
# ##Ejercicio elaborado por Santiago Varela #3

# %%
resultados =[]
n = int(input("ingrese la cantidad de numeros que desee verificar"))
c=0
while n >= c:
  numero = int(input("ingrese un numero: "))
  c=c+1

  ultimo_digito = numero % 10
  if ultimo_digito % 2 == 0:
    resultados.append("par")
  else:
    resultados.append("impar")
    n-=1
i = 0;
while (i <= n+1):
  print (f"el ultimo digito del numero {i+1} es {resultados[i]}")
i=i+1
# Out:
# Streaming output truncated to the last 5000 lines.
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# el ultimo digito del numero 1 es impar
# ...

# %%
#Ejercicio 19 Laura Vargas
#Usando for
for numero in range(13,48):
  if numero % 5==0:
    print(numero)
# Out:
# 15
# 20
# 25
# 30
# 35
# 40
# 45

# %%
#Usando while
numero=13
while numero <= 48:
    if numero % 5 == 0:
        print(numero)
    numero += 1
# Out:
# 15
# 20
# 25
# 30
# 35
# 40
# 45

# %% [markdown]
# #Recordatorio: no cerrar el colab
