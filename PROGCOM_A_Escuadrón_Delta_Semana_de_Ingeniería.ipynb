# %% [markdown]
# <a href="https://colab.research.google.com/github/Lifestaxx/PROGCOM-A/blob/main/PROGCOM_A_Escuadr%C3%B3n_Delta_Semana_de_Ingenier%C3%ADa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1. FOTO DEL EQUIPO: Escuadron Delta [PROGCOM-A]
#
# - Juan Diego Suarez
# - Santiago Sanabria
# - Santiago Varela
#
# ![e2973a92-f7ab-4d76-9505-4f608b539c25.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #2. Aspectos importantes del foro

# %% [markdown]
# - Toma de decisiones auto gestionada y la toma de datos en la IA: la IA tiene un cebo algorítmico de la toma de datos, cebo de la construcción de la base de datos que se usa en categorías para identificar reconocimiento facial, la transparencia del proceso de información, puede tener cebos desconocidos, las tecnologías pueden contener esos cebos o no.
#
# - El papel que las empresas emplean en la IA en la ética de su desarrollo y gratificación: existen leyes penales que no siempre se cumplen, las industrias no cumplen tampoco, como sociedad que nivel de ética se maneja? Los niños se están educando en la guajira con Etica y lo que se espera es que se eduquen con Etica moderna, un algoritmo canaliza los datos con lo que queda de resultado es facilitar algunos procesos, como sociedad debemos tener algún sitio en donde podemos desahogarnos de algunos algoritmos, como comunicación sería mejor que nos brinden facilidad para poder cooperar con diferentes algoritmos.
#
# - Los profesionales cómo garantizan sus productos de manera Ética: la manipulación de la perfección, la capacidad que tiene el que quiere manipular, lo que es real o no es complicado, el conocimiento de realidad es completamente verídica, estamos sujetos a manipulación, todo se basa en algoritmos, si se lleva a un tema política no estará disponible al resto de opiniones, la capacidad de poder hacer es una gran ayuda por parte de la IA,  llega a la verdad de la sociedad sobre la verdad absoluta, no hay forma de negar la realidad, empeora la sociedad gran parte, tenemos un arma súper poderosa ya que para poder regular sería manejarla con Ética, no debemos caer en esa situación de cómputo.

# %% [markdown]
# #3. Proyectos presentados en semilleros

# %% [markdown]
# 1- Las Zonas no interconectadas (ZNI) de en el Indicador de pertinencia
# Colombia presentan un déficit abastecimiento energético que se ha abordado principalmente por medio del combustible diésel, sujeto a altos costos de transporte, además de fuentes renovables, donde normalmente se usa la fuente solar Fotovoltaica la cual está sujeta a fluctuaciones no controlables y altos costos en las baterías de almacenamiento.
# Estas ZNI cuentan con gasificación de biomasa aprovechable que junto al potencial solar fotovoltaico permite stimar un indicador de pertinencia para la licación de estas fuentes renovables como globalizacion energetica para cada localidad de ZNI de Colombia
#
# 2- Proceso de desarrollar
# - Datos de servicio
# - Datos de biomasa
# - Datos de irradiación solar
#
# - Datos de servicio
# -- Limpieza de datos
# -- Normalizacion
# -- Agregación
# -- Ponderacion
#
# - Datos de irradiación solar
# -- Estocasticidad
#
# Universidad Autónoma de Bucaramanga - Ingenieria en Energías

# %% [markdown]
# 2- FORMACIÓN TEÓRICO-EXPERIMENTAL EN CONCEPTOS SOBRE FACTORES FISICOQUÍMICOS RELEVANTES PARA LA APROPIACIÓN DEL CONOCIMIENTO DEL "NEXUS AGUA-ENERGÍA" FASE II: FORTALECIMIENTO DE COMPETENCIAS PARA ESTUDIOS AMBIENTALES.
#
# El proposito del proyecto es profesionales del area de la ingenieria en la complejidad y profundidad de los temas relacionados con el nexus Agua-energia evolucionando semestre a semestre, fortaleciendo a su vez, competencias en tematicas ambientales como la huella de carbono con el fin de formular proyectos de ingenieria aplicada que promuevan iniciativas de bioeconomia circular.
#
# - Resultados esperados:
# -- Manual-Guia laboratorio
# -- Articulo-Semillero-Potencia
# -- Apropiacion del conocimiento-Fortalecimiento
# -- Formulacion de un proyecto de grado
#
# - Conclusiones:
# -- Apropiacion del conocimiento
# -- Proceso formativo a largo plazo
# -- Relacion UNAB-Entidades-Comunidades
#
# Universidad Autónoma de Bucaramanga - Ingeniería en Energía

# %% [markdown]
# 3- MECANIZADO DE UN MATERIAL BIOCOMPUESTO:
# En el tramscurso del proceso se analizaran los parametros como la fuerza de corte, la rugosidad superficial y la calidad de las piezas mecanizada. se compararán los resultados con los obtenidos al mecanizar otros materiales similares, con el fin de determinare la capacidad del material biocompuesto en términos de su maquinabilidad. se va a examinar los efectos del mecanizado en las propiedades mecánicas del material biocompuesto. Se realizaran pruebas de resistencia y rigidez en las piezas mecanizadas con el fin de evaluar posibles cambios en comparación con el material sin mecanizar. Se busca que la investigacion demuestre que el mecanizado con el torno CNC del material a base de semillas de aguacate y poliéster sea factible
#
# - Objetivo General:
# El objetivo general de la investigacion es explorar las caracteristicas del mecanizado con control numerico computarizado CNC en un material biocompuesto.
#
# - Objetivos Especificos
# 1. Se identificarán pruebas de mecanizado con torno CNC
# 2. Se describiran las variables como la velocidad de corte, velocidad de avance y profundidad de corte con el fin de determinar las condiciones optimas del mecanizado
# 3. Establecer las condiciones optimas de mecanizado y evaluar los efectos en las propiedaes mecanicas
#
# - Presentacion esquematica del proceso
# -- Rayado papa aguacate
# -- Pepa de aguacate rayado
# -- Mezcla de poliéster con pepa rayada de aguacate
# -- Material preparado en vasos
#
# Universidad investigacíon y desarrollo UDI Grupo de investigacion Hoshin

# %% [markdown]
# 4- EVALUACION DE LA RESPUESTA MECÁNICA DE HIDROGELES DE AGAROSA Y PLASMA POBRE EN PLAQUETAS, PARA EL ANÁLISIS DE SU COMPORTAMIENTO VISCOELÁSTICO:
# La reparacion de lesiones en tejidos blandos cuando el paciente tiene deficiencias en sus mecanismos de regeneracion e s uno de los grandes retos de la medicina moderna
#
# 1. La manera tradicional de tratar este tipo de problematicas es mediante el uso de apósitos. sin embargo, se ha encontrado que se necesita cumplir no solo con requisitos especificos como lo son las propiedades mecanicas, viscoelasticas y absorcion de agua para garantizar la cicatrizacion
#
# 2. Sino que tambien, la entrega de moleculas de señalizacion celular se hace fundamentalmente lograr la curacion de la herida
#
# 3. En el presente trabajo se planteo la fabricacion de hidrogeles a base de agarosa y plasma pobre en plaquetas PPP que podrian ser utilizados como apositos que promuevan la cicatrizacion de heridas en tejidos blandos; para esto se evaluaran sus propiedades viscoelasticas y de absorcion de agua, proponiendo un modelo matematico que permita relacionar ambos comportamientos.
#
# - Objetivo general
# Analizar la composicion de hidrogeles a base de PPP y agarosa que genera un balance entre las propiedades viscoelasticas y la absorcion del agua
#
# - Objetivos Especificos
#
# -- Establecer la capacidad de absorcion del agua de los hidrogeles a base de agarosa
#
# -- Caracterizar la respuesta viscoelastica de los hidrogeles de agarosa y PPP por medio de esfuerzos de comprension
#
# -- Interpretar las respuestas de absorcion de agua y viscoelasticidad de los hidrogeles a base de agarosa y PPP mediante modelos estadisticos
#
#
# - Resultados
# Se ha observado en los resultados preliminares que la concentracion de PPP aparentemente influye en la capacidad de perder peso en el tiempo, lo que seria un indicio de liberacion de moleculas de señalizacion en medios acuosos, lo que apuntaria a que los apositos propuestos servirian para mejorar el proceso de cicatrizacion
#
# Universidad Autónoma de Bucaramanga

# %% [markdown]
# 4- CQ2 CAPTURE USING A BIOCHART COLUMN SYSTEM FOR INDUSTRIAL PROCESSES
#
# Esquema Industrial: Efectos de la investigacion de la fabrica moderna a partir del siglo XVIII Aparicion de nuevas fuentes de energia, division del trabajo, necesidad de nuevas inversiones, gran crecimiento urbano
#
# Tipos de industrias o principales sectores productivos industriales.
# se agrupan en relacion a las materias predominantes, y son:
#
# - Industria metalurgica: de base siderurgica-metalurgica y de transformacion o mecanica.
#
# - Industria del cemento o la construccion
# - otros sectores productivos: de consumo (textil, agroalimentaria)
#
# Universidad de Santander
